# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv(r'C:\Users\lenovo\Desktop\Preprocess\yelp_business_dataset_italian_restaurant (1).csv')

# %%
data['name']
# Out:
# 0                  Helena Avenue Bakery
# 1       Santa Barbara Shellfish Company
# 2          California Tacos and Taproom
# 3                         Marty's Pizza
# 4                              Cal Taco
#                      ...
# 1540            Good Stuff Baked Treats
# 1541        Woody's Roundup Bar & Grill
# 1542                        Vino Divino
# 1543                  Kyle's Isla Vista
# 1544                         Pizza Guru
# Name: name, Length: 1545, dtype: object

# %%
dropped_na_data=data.dropna()

# %%
dropped_na_data
# Out:
#                  business_id                             name           city  \
# 0     IDtLPgUrqorrpqSLdfMhZQ             Helena Avenue Bakery  Santa Barbara
# 1     SZU9c8V2GuREDN5KgyHFJw  Santa Barbara Shellfish Company  Santa Barbara
# 2     4xhGQGdGqU60BIznBjqnuA     California Tacos and Taproom     Isla Vista
# 3     ifjluUv4VASwmFqEp8cWlQ                    Marty's Pizza  Santa Barbara
# 4     VeFfrEZ4iWaecrQg6Eq4cg                         Cal Taco         Goleta
# ...                      ...                              ...            ...
# 1540  IRBhPAC4ZoDpXazpoB3epQ          Good Stuff Baked Treats  Santa Barbara
# 1541  TSwMwVq5GtQh5LW2t32uGA      Woody's Roundup Bar & Grill  Santa Barbara
# 1542  Bo-GGwQNcLVwyKeYkbfAYg                      Vino Divino  Santa Barbara
# 1543  8BUr8GviR2o_b-brO21wwQ                Kyle's Isla Vista     Isla Vista
# 1544  uriD7RFuHhLJeDdKaf0nFA                       Pizza Guru  Santa Barbara
#
# ...

# %%
dropped_na_data['state'].value_counts()
# Out:
# CA    1524
# Name: state, dtype: int64

# %%
# filter out fast food restaurants

filtered_data = dropped_na_data[dropped_na_data['categories'].str.contains('Fast Food')]
filtered_data
# Out:
#                  business_id                             name           city  \
# 9     vLT1KtrA9bWvjFOg-0xVIg                Pieology Pizzeria         Goleta
# 13    Hqz96v1ymucUKNzIWfEKXw                           Subway  Santa Barbara
# 44    bbEXAEFr4RYHLlZ-HFssTA  The Original Habit Burger Grill         Goleta
# 55    Wy8Hswf2cLQGRZN6armkag                  Jack in the Box         Goleta
# 60    DzpaiMQnB_sNhZPrgdvKHg                  Sushiya Express         Goleta
# ...                      ...                              ...            ...
# 1481  kAGknILVe6xCv9a2uc5JHw                           Subway    Carpinteria
# 1485  iFlEWAwE1MwcXREzgLNIsQ                     Pick Up Stix         Goleta
# 1500  ArIXofDAcFztX8Ry0_81sw                       Carl's Jr.    Carpinteria
# 1512  PsO9LleYQJlFc_r-DJxVzg                        Taco Bell  Santa Barbara
# 1522  fVUurZgbWXzp2QzDzJzmpA                  Pickles & Swiss  Santa Barbara
#
# ...

# %%
filtered_data['name'].value_counts()
# Out:
# Subway                             10
# McDonald's                          7
# Taco Bell                           6
# Jersey Mike's Subs                  4
# Jack in the Box                     3
# Chipotle Mexican Grill              3
# Carl's Jr                           3
# El Pollo Loco                       2
# Blaze Pizza                         2
# KFC                                 2
# Carl's Jr.                          2
# Blenders In The Grass               1
# One Piece                           1
# Pick Up Stix                        1
# Uncle Roccos Famous NY Pizza        1
# Wendy's                             1
# East Beach Tacos                    1
# Costco Food Court                   1
# goa taco                            1
# Naan Stop                           1
# Sushiya Express                     1
# Pieology Pizzeria                   1
# Persona Pizzeria                    1
# Yoshinoya                           1
# SB Munchiez                         1
# ...

# %%
# delete filtered data

new_data = dropped_na_data[~dropped_na_data['categories'].str.contains('Fast Food')]
new_data
# Out:
#                  business_id                             name           city  \
# 0     IDtLPgUrqorrpqSLdfMhZQ             Helena Avenue Bakery  Santa Barbara
# 1     SZU9c8V2GuREDN5KgyHFJw  Santa Barbara Shellfish Company  Santa Barbara
# 2     4xhGQGdGqU60BIznBjqnuA     California Tacos and Taproom     Isla Vista
# 3     ifjluUv4VASwmFqEp8cWlQ                    Marty's Pizza  Santa Barbara
# 4     VeFfrEZ4iWaecrQg6Eq4cg                         Cal Taco         Goleta
# ...                      ...                              ...            ...
# 1540  IRBhPAC4ZoDpXazpoB3epQ          Good Stuff Baked Treats  Santa Barbara
# 1541  TSwMwVq5GtQh5LW2t32uGA      Woody's Roundup Bar & Grill  Santa Barbara
# 1542  Bo-GGwQNcLVwyKeYkbfAYg                      Vino Divino  Santa Barbara
# 1543  8BUr8GviR2o_b-brO21wwQ                Kyle's Isla Vista     Isla Vista
# 1544  uriD7RFuHhLJeDdKaf0nFA                       Pizza Guru  Santa Barbara
#
# ...

# %%
# convert new_data to a csv file

csv = new_data.to_csv(r'C:\Users\lenovo\Desktop\Preprocess\cleaned.csv', index=False)

# %%
new_data_cleaned = new_data[new_data['categories'].str.contains('Italian')]
new_data_cleaned
# Out:
#                  business_id                         name           city  \
# 6     xwSWtJcQkzTF6HNm_IMgcg         Rusty's Pizza Parlor         Goleta
# 26    V4lqQdll3_TAEtkrHDYbAA         Italia Pizza & Pasta         Goleta
# 38    j-lxie7nEh3UeUTpiqekkQ                 Presto Pasta  Santa Barbara
# 47    uI15YInpDsGBUZcNfm_TfQ  Borrello's Pizza & Pastaria    Carpinteria
# 79                    #NAME?                  Pizza Mizza  Santa Barbara
# ...                      ...                          ...            ...
# 1447  TYVln68leW7BYuVksFyB5A                      Sevilla  Santa Barbara
# 1455  54oLdsGU9B8HxFTqCCqV-A               Via Maestra 42  Santa Barbara
# 1475  PgtqA056auCp5EbcZMbXPQ             Trattoria Mollie  Santa Barbara
# 1517  Qkg16mN-8QR66gjzg6gMyw   Convivo Restaurant and Bar  Santa Barbara
# 1530  HrnSaz2f1WUEoAQQ6iD6gw               Lemon Tree Inn  Santa Barbara
#
#      state  postal_code   latitude   longitude  stars  review_count  is_open  \
# ...

# %%
csv1 = new_data_cleaned.to_csv(r'C:\Users\lenovo\Desktop\Preprocess\cleaned_italian.csv', index=False)

# %%
new_data_cleaned = new_data[~new_data['categories'].str.contains('Shopping')]
new_data_cleaned
# Out:
#                  business_id                             name           city  \
# 0     IDtLPgUrqorrpqSLdfMhZQ             Helena Avenue Bakery  Santa Barbara
# 1     SZU9c8V2GuREDN5KgyHFJw  Santa Barbara Shellfish Company  Santa Barbara
# 2     4xhGQGdGqU60BIznBjqnuA     California Tacos and Taproom     Isla Vista
# 3     ifjluUv4VASwmFqEp8cWlQ                    Marty's Pizza  Santa Barbara
# 4     VeFfrEZ4iWaecrQg6Eq4cg                         Cal Taco         Goleta
# ...                      ...                              ...            ...
# 1540  IRBhPAC4ZoDpXazpoB3epQ          Good Stuff Baked Treats  Santa Barbara
# 1541  TSwMwVq5GtQh5LW2t32uGA      Woody's Roundup Bar & Grill  Santa Barbara
# 1542  Bo-GGwQNcLVwyKeYkbfAYg                      Vino Divino  Santa Barbara
# 1543  8BUr8GviR2o_b-brO21wwQ                Kyle's Isla Vista     Isla Vista
# 1544  uriD7RFuHhLJeDdKaf0nFA                       Pizza Guru  Santa Barbara
#
# ...

# %%
csv3 = new_data_cleaned.to_csv(r'C:\Users\lenovo\Desktop\Preprocess\cleaned_no_shopping and fast food.csv', index=False)

# %%
# filter out data that contains 'Restaurants' and 'Food' in the categories

filtered_data_1 = new_data[new_data['categories'].str.contains('Restaurants')]
filtered_data_1 = filtered_data_1[filtered_data_1['categories'].str.contains('Food')]

filtered_data_1
# Out:
#                  business_id                                      name  \
# 0     IDtLPgUrqorrpqSLdfMhZQ                      Helena Avenue Bakery
# 1     SZU9c8V2GuREDN5KgyHFJw           Santa Barbara Shellfish Company
# 5     bdfZdB2MTXlT6-RBjSIpQg                                Pho Bistro
# 12    UFpCraqzFBAhtZqmxmiWsA                               Cat Therapy
# 14    JWFpjvCc_nkNDVtMPx1ZGg                                   Bogo SB
# ...                      ...                                       ...
# 1529  hDr_bt6MEwlGvGCCKzyzhg  Goleta Coffee Co and Loca Vivant Kitchen
# 1533  fzDcZVrT5XQmd1t_W0AguQ                             Flaming Grill
# 1537  izSgTrqebu8bN8ONOCs6cQ                                Oat Bakery
# 1543  8BUr8GviR2o_b-brO21wwQ                         Kyle's Isla Vista
# 1544  uriD7RFuHhLJeDdKaf0nFA                                Pizza Guru
#
#                city state  postal_code   latitude   longitude  stars  \
# ...
