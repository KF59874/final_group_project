# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv(r'D:\Downloads\review_data.csv')

# %%
data
# Out:
#                      review_id             business_id  \
# 0       L0jv8c2FbpWSlfNC6bbUEA  IDtLPgUrqorrpqSLdfMhZQ
# 1       LFpaQzYkP5Pzm5lEjJpTRw  IDtLPgUrqorrpqSLdfMhZQ
# 2       Q3fPo_x6xKxafAzy1hFITg  IDtLPgUrqorrpqSLdfMhZQ
# 3       _OmwsZRl7Qrz7S2T8mnlRg  IDtLPgUrqorrpqSLdfMhZQ
# 4       xinTYNBQflqAoKYBAztv2A  IDtLPgUrqorrpqSLdfMhZQ
# ...                        ...                     ...
# 230883  NxzOAsRXwO1OqEPfthVX7w  KSYONgGtrK0nKXfroB-bwg
# 230884  TQqqAtRS-1MI8gtkZWiALg  GuzbBFraIq-fbkjfvaTRvg
# 230885  UKSGqYVh1g5opUOM4FLIlQ  iT78kOB6Ja3BJQdYipPa5g
# 230886  pJvL9AN6gDoixiLLNF1c7w  r2IhvKZQ_wLR5mLBnPOilg
# 230887  aGiUeKfrQx5tNLOpPYo7QQ  U1Gc3wKN5viu_e68KJVOdQ
#
#                                              name           city state  \
# 0                            Helena Avenue Bakery  Santa Barbara    CA
# 1                            Helena Avenue Bakery  Santa Barbara    CA
# 2                            Helena Avenue Bakery  Santa Barbara    CA
# ...

# %%
data_1 = data.dropna(axis=0)

# %%
data_1
# Out:
#                      review_id             business_id  \
# 0       L0jv8c2FbpWSlfNC6bbUEA  IDtLPgUrqorrpqSLdfMhZQ
# 1       LFpaQzYkP5Pzm5lEjJpTRw  IDtLPgUrqorrpqSLdfMhZQ
# 2       Q3fPo_x6xKxafAzy1hFITg  IDtLPgUrqorrpqSLdfMhZQ
# 3       _OmwsZRl7Qrz7S2T8mnlRg  IDtLPgUrqorrpqSLdfMhZQ
# 4       xinTYNBQflqAoKYBAztv2A  IDtLPgUrqorrpqSLdfMhZQ
# ...                        ...                     ...
# 230883  NxzOAsRXwO1OqEPfthVX7w  KSYONgGtrK0nKXfroB-bwg
# 230884  TQqqAtRS-1MI8gtkZWiALg  GuzbBFraIq-fbkjfvaTRvg
# 230885  UKSGqYVh1g5opUOM4FLIlQ  iT78kOB6Ja3BJQdYipPa5g
# 230886  pJvL9AN6gDoixiLLNF1c7w  r2IhvKZQ_wLR5mLBnPOilg
# 230887  aGiUeKfrQx5tNLOpPYo7QQ  U1Gc3wKN5viu_e68KJVOdQ
#
#                                              name           city state  \
# 0                            Helena Avenue Bakery  Santa Barbara    CA
# 1                            Helena Avenue Bakery  Santa Barbara    CA
# 2                            Helena Avenue Bakery  Santa Barbara    CA
# ...

# %%
# retrieve only italian restaurants


data_1 = data_1[data_1['categories'].str.contains('Italian')]
data_1
# Out:
#                      review_id             business_id  \
# 48      FNXvn55vcpxyf7najE2vJA  xwSWtJcQkzTF6HNm_IMgcg
# 49      JppBfMoyid1t7pOAw65Yqw  xwSWtJcQkzTF6HNm_IMgcg
# 134     JEP_e5vAKDv5z0-IwS82Yw  uI15YInpDsGBUZcNfm_TfQ
# 135     M8Ugk0S5VVDWA6oCEN9stg  uI15YInpDsGBUZcNfm_TfQ
# 222     c3qUUA4t9MxpGvBKR1_nAw  lq7dE9c10OvRfd_edJoyMg
# ...                        ...                     ...
# 230781  t9gdT9Qhtgfs4mXapVutcg  Qkg16mN-8QR66gjzg6gMyw
# 230782  WSbA-C3O0NmpLw6TnE3jAw  Qkg16mN-8QR66gjzg6gMyw
# 230783  yhpNUVcsr15gDON1Gp4fBQ  Qkg16mN-8QR66gjzg6gMyw
# 230856  _mMR_CGJg_UcmQLqzhui9Q  HrnSaz2f1WUEoAQQ6iD6gw
# 230857  163OOT_ND_zx2eLmyqR94g  HrnSaz2f1WUEoAQQ6iD6gw
#
#                                name           city state  postal_code  \
# 48             Rusty's Pizza Parlor         Goleta    CA        93117
# 49             Rusty's Pizza Parlor         Goleta    CA        93117
# 134     Borrello's Pizza & Pastaria    Carpinteria    CA        93013
# ...

# %%
csv = data_1.to_csv(r'D:\Downloads\review_data_italian.csv', index=False)
